# %%
import pandas as pd

# %%
pd.set_option('max_colwidth',1000)
pd.set_option('max_seq_items','none')
# read csvs as data frames
images = pd.read_csv('imagesonline.csv').astype(str)
characters_images = pd.read_csv('characters_images.csv').astype(str) 
kashira_images = pd.read_csv('kashira_images.csv').astype(str) 
performances_images = pd.read_csv('performances_images.csv').astype(str) 
performers_images = pd.read_csv('performers_images.csv').astype(str)
plays_images = pd.read_csv('plays_images.csv').astype(str) 
productions_images = pd.read_csv('productions_images.csv').astype(str) 
scenes_images = pd.read_csv('scenes_images.csv').astype(str) 
tags_images = pd.read_csv('tags_images.csv').astype(str)

# %%
images = images.drop('online', 1)

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
def multiValDataFrame(df, table_id, multival_id):
    new_df = pd.DataFrame({})
    cols = df.columns
    id_list = df[table_id].unique()

    for i in log_progress(id_list):
        temp_row = df.loc[df[table_id] == i ]
        vals = []
        for col in cols:
            vals.append(temp_row[:1][col].values[0])
        
        temp_dict = dict(zip(cols, vals))
        multi_id_list = list(temp_row[multival_id])
    
        temp_dict[multival_id] = multi_id_list
        
        new_df = new_df.append(temp_dict, ignore_index=True)
    return new_df

# %%
# merge and multival characters
images = pd.merge(images, characters_images, on='image_id', how='outer').fillna('')

# %%
images = multiValDataFrame(images, 'image_id', 'character_id')
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
# merge and multival kashira
images = pd.merge(images, kashira_images, on='image_id', how='outer')
# Out:
#                           character_id colser_id container_number  \
# 0      [452, 453, 454, 455, 456, 2312]         2             46.0
# 1      [452, 453, 454, 455, 456, 2312]         2             46.0
# 2      [452, 453, 454, 455, 456, 2312]         2             46.0
# 3           [453, 454, 455, 452, 2312]         2             46.0
# 4                     [452, 454, 2312]         2             46.0
# 5                                [456]         2             46.0
# 6           [453, 454, 455, 452, 2312]         2             46.0
# 7                                [452]         2             46.0
# 8      [452, 453, 454, 455, 456, 2312]         2             46.0
# 9                                [452]         2             46.0
# 10                               [453]         2             46.0
# 11                               [453]         2             46.0
# 12                          [453, 452]         2             46.0
# 13                          [453, 452]         2             46.0
# 14                                  []         2             46.0
# 15                          [454, 453]         2             46.0
# 16                               [452]         2             46.0
# 17                          [456, 454]         2             46.0
# 18                               [452]         2             46.0
# 19                     [460, 468, 459]         2             46.0
# 20                          [460, 468]         2             46.0
# 21                               [459]         2             46.0
# 22                               [460]         2             46.0
# 23                          [460, 468]         2             46.0
# 24                     [458, 460, 468]         2             46.0
# 25           [461, 459, 458, 460, 468]         2             46.0
# 26                               [458]         2             46.0
# 27                          [458, 460]         2             46.0
# 28                               [460]         2             46.0
# 29                          [458, 460]         2             46.0
# ...                                ...       ...              ...
# 19152                            [427]
# 19153                            [532]
# 19154                           [1018]
# 19155                            [683]
# 19156                           [1203]
# 19157                            [774]
# 19158                     [1034, 1040]
# 19159                           [1040]
# 19160                            [711]
# 19161                            [798]
# 19162                            [134]
# 19163                            [129]
# 19164                             [43]
# 19165                             [42]
# 19166                            [370]
# 19167                            [370]
# 19168                            [370]
# 19169                            [370]
# 19170                       [780, 779]
# 19171                       [780, 786]
# 19172                       [780, 779]
# 19173                            [780]
# 19174                            [780]
# 19175                       [780, 779]
# 19176                       [780, 779]
# 19177                            [504]
# 19178                            [129]
# 19179                            [387]
# 19180                         [42, 43]
# 19181                         [42, 46]
#
#       container_type            creator image_id item_id media_type  \
# 0       Slide Binder  Barbara C. Adachi     8281    0001      slide
# 1       Slide Binder  Barbara C. Adachi     8282    0002      slide
# 2       Slide Binder  Barbara C. Adachi     8283    0003      slide
# 3       Slide Binder  Barbara C. Adachi     8284    0004      slide
# 4       Slide Binder  Barbara C. Adachi     8285    0005      slide
# 5       Slide Binder  Barbara C. Adachi     8286    0006      slide
# 6       Slide Binder  Barbara C. Adachi     8287    0007      slide
# 7       Slide Binder  Barbara C. Adachi     8288    0008      slide
# 8       Slide Binder  Barbara C. Adachi     8289    0009      slide
# 9       Slide Binder  Barbara C. Adachi     8290    0010      slide
# 10      Slide Binder  Barbara C. Adachi     8291    0011      slide
# 11      Slide Binder  Barbara C. Adachi     8292    0012      slide
# 12      Slide Binder  Barbara C. Adachi     8293    0013      slide
# 13      Slide Binder  Barbara C. Adachi     8294    0014      slide
# 14      Slide Binder  Barbara C. Adachi     8295    0015      slide
# 15      Slide Binder  Barbara C. Adachi     8296    0016      slide
# 16      Slide Binder  Barbara C. Adachi     8297    0017      slide
# 17      Slide Binder  Barbara C. Adachi     8298    0018      slide
# 18      Slide Binder  Barbara C. Adachi     8299    0019      slide
# 19      Slide Binder  Barbara C. Adachi     8300    0020      slide
# 20      Slide Binder  Barbara C. Adachi     8301    0021      slide
# 21      Slide Binder  Barbara C. Adachi     8302    0022      slide
# 22      Slide Binder  Barbara C. Adachi     8303    0023      slide
# 23      Slide Binder  Barbara C. Adachi     8304    0024      slide
# 24      Slide Binder  Barbara C. Adachi     8305    0025      slide
# 25      Slide Binder  Barbara C. Adachi     8306    0026      slide
# 26      Slide Binder  Barbara C. Adachi     8307    0027      slide
# 27      Slide Binder  Barbara C. Adachi     8308    0028      slide
# 28      Slide Binder  Barbara C. Adachi     8309    0029      slide
# 29      Slide Binder  Barbara C. Adachi     8310    0030      slide
# ...              ...                ...      ...     ...        ...
# 19152                                      64470
# 19153                                      64485
# 19154                                      64487
# 19155                                      64493
# 19156                                      64497
# 19157                                      64535
# 19158                                      64536
# 19159                                      64537
# 19160                                      64539
# 19161                                      64540
# 19162                                      64541
# 19163                                      64542
# 19164                                      64544
# 19165                                      64545
# 19166                                      64557
# 19167                                      64558
# 19168                                      64559
# 19169                                      64560
# 19170                                      64564
# 19171                                      64565
# 19172                                      64566
# 19173                                      64567
# 19174                                      64568
# 19175                                      64569
# 19176                                      64570
# 19177                                      64572
# 19178                                      64573
# 19179                                      64574
# 19180                                      64575
# 19181                                      64576
#
#       notes_on_item                           objid sequence_number  \
# 0                 2  ldpd_bun_slide_452_2_0001_0001            0001
# 1                 6  ldpd_bun_slide_452_2_0002_0002            0002
# 2                 7  ldpd_bun_slide_452_2_0003_0003            0003
# 3                 0  ldpd_bun_slide_452_2_0004_0004            0004
# 4                 4  ldpd_bun_slide_452_2_0005_0005            0005
# 5                 1  ldpd_bun_slide_452_2_0006_0006            0006
# 6                 1  ldpd_bun_slide_452_2_0007_0007            0007
# 7                 2  ldpd_bun_slide_452_2_0008_0008            0008
# 8                 5  ldpd_bun_slide_452_2_0009_0009            0009
# 9                 3  ldpd_bun_slide_452_2_0010_0010            0010
# 10                4  ldpd_bun_slide_452_2_0011_0011            0011
# 11                7  ldpd_bun_slide_452_2_0012_0012            0012
# 12                3  ldpd_bun_slide_452_2_0013_0013            0013
# 13                4  ldpd_bun_slide_452_2_0014_0014            0014
# 14                5  ldpd_bun_slide_452_2_0015_0015            0015
# 15                6  ldpd_bun_slide_452_2_0016_0016            0016
# 16                7  ldpd_bun_slide_452_2_0017_0017            0017
# 17                9  ldpd_bun_slide_452_2_0018_0018            0018
# 18               10  ldpd_bun_slide_452_2_0019_0019            0019
# 19               11  ldpd_bun_slide_452_2_0020_0020            0020
# 20                8  ldpd_bun_slide_453_2_0021_0021            0021
# 21                9  ldpd_bun_slide_453_2_0022_0022            0022
# 22               10  ldpd_bun_slide_453_2_0023_0023            0023
# 23               11  ldpd_bun_slide_453_2_0024_0024            0024
# 24               12  ldpd_bun_slide_453_2_0025_0025            0025
# 25               12  ldpd_bun_slide_453_2_0026_0026            0026
# 26               14  ldpd_bun_slide_453_2_0027_0027            0027
# 27               13  ldpd_bun_slide_453_2_0028_0028            0028
# 28               15  ldpd_bun_slide_453_2_0029_0029            0029
# 29               16  ldpd_bun_slide_453_2_0030_0030            0030
# ...             ...                             ...             ...
# 19152
# 19153
# 19154
# 19155
# 19156
# 19157
# 19158
# 19159
# 19160
# 19161
# 19162
# 19163
# 19164
# 19165
# 19166
# 19167
# 19168
# 19169
# 19170
# 19171
# 19172
# 19173
# 19174
# 19175
# 19176
# 19177
# 19178
# 19179
# 19180
# 19181
#
#       series_number slidepage_folder_no
# 0               2.0               452.0
# 1               2.0               452.0
# 2               2.0               452.0
# 3               2.0               452.0
# 4               2.0               452.0
# 5               2.0               452.0
# 6               2.0               452.0
# 7               2.0               452.0
# 8               2.0               452.0
# 9               2.0               452.0
# 10              2.0               452.0
# 11              2.0               452.0
# 12              2.0               452.0
# 13              2.0               452.0
# 14              2.0               452.0
# 15              2.0               452.0
# 16              2.0               452.0
# 17              2.0               452.0
# 18              2.0               452.0
# 19              2.0               452.0
# 20              2.0               453.0
# 21              2.0               453.0
# 22              2.0               453.0
# 23              2.0               453.0
# 24              2.0               453.0
# 25              2.0               453.0
# 26              2.0               453.0
# 27              2.0               453.0
# 28              2.0               453.0
# 29              2.0               453.0
# ...             ...                 ...
# 19152
# 19153
# 19154
# 19155
# 19156
# 19157
# 19158
# 19159
# 19160
# 19161
# 19162
# 19163
# 19164
# 19165
# 19166
# 19167
# 19168
# 19169
# 19170
# 19171
# 19172
# 19173
# 19174
# 19175
# 19176
# 19177
# 19178
# 19179
# 19180
# 19181
#
# [19182 rows x 13 columns]

# %%
images = multiValDataFrame(images, 'image_id', 'kashira_id')
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-cb94f6bbc57c> in <module>()
# ----> 1 images = multiValDataFrame(images, 'image_id', 'kashira_id')
#
# <ipython-input-5-cc77899963cf> in multiValDataFrame(df, table_id, multival_id)
#      14
#      15         temp_dict = dict(zip(cols, vals))
# ---> 16         multi_id_list = list(temp_row[multival_id])
#      17
#      18         temp_dict[multival_id] = multi_id_list
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /usr/local/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'kashira_id'

# %%
# merge and multival performances
images = pd.merge(images, performances_images, on='image_id', how='outer')

# %%
images = multiValDataFrame(images, 'image_id', 'performance_id')

# %%
# merge and multival performers
images = pd.merge(images, performers_images, on='image_id', how='outer')

# %%
images = multiValDataFrame(images, 'image_id', 'performer_id')

# %%
# merge and multival plays
images = pd.merge(images, plays_images, on='image_id', how='outer')

# %%
images = multiValDataFrame(images, 'image_id', 'play_id')

# %%
# merge and multival productions
images = pd.merge(images, productions_images, on='image_id', how='outer')

# %%
images = multiValDataFrame(images, 'image_id', 'production_id')

# %%
# merge and multival scenes
images = pd.merge(images, scenes_images, on='image_id', how='outer')

# %%
images = multiValDataFrame(images, 'image_id', 'scene_id')

# %%
# merge and multival tags
images = pd.merge(images, tags_images, on='image_id', how='outer')

# %%
images = multiValDataFrame(images, 'image_id', 'subject_id')

# %%
images.rename(columns = {'subject_id':'tag_id'}, inplace = True)

# %%
images = images[['image_id','media_type','character_id','tag_id','kashira_id','performance_id','performer_id','play_id','production_id','scene_id','container_number','container_type','creator','item_id','colser_id','notes_on_item','objid','sequence_number','series_number','slidepage_folder_no']]

# %%
# csvname = 'images_exp.csv'
# images.to_csv(csvname, encoding='utf8')

# %%
# jsonname = 'images_exp.json'
# images.to_json(jsonname, orient='records', force_ascii=False)
